# %%
import google.generativeai as genai
import logging
import pandas as pd
import os
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type
from ratelimit import limits, sleep_and_retry
import csv

# Enable logging for debugging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Configure Gemini API
API_KEY = ''  # Replace with your actual API key or use os.getenv
genai.configure(api_key=API_KEY)

# CSV file to read and update
CSV_FILE = 'paperclip_uses.csv'

# %%
# Rate limit: 15 calls per minute (60 seconds / 15 = 4 seconds per call)
CALLS_PER_MINUTE = 15
PERIOD = 60  # seconds

# Save after every 10 validations
SAVE_INTERVAL = 15

# Prompt for validating a use
VALIDATION_PROMPT = """
You are an expert validator for creative uses of a small, bendable metal wire (3-5 cm long, thin, non-conductive), similar to a paperclip but without mentioning 'paperclip'.

Evaluate the following use: "{use}" in the category: "{category}"

Determine if this is a valid, feasible, and novel use for such a wire. Consider whether the use is practical and makes sense given the wire's properties (small, bendable, non-conductive). Avoid electrical or unrealistic uses.

Output in this exact format:
Valid: Yes/No
Explanation: [Your brief explanation]
"""

class WireUsesValidator:
    def __init__(self):
        self.validated_data = []

    def load_data(self):
        """Load uses and categories from the input CSV"""
        if not os.path.exists(CSV_FILE):
            logging.error(f"{CSV_FILE} does not exist. Run the generation script first.")
            return pd.DataFrame()
        
        try:
            df = pd.read_csv(CSV_FILE, on_bad_lines='skip')
            if 'Use' not in df.columns or 'Category' not in df.columns:
                logging.error(f"{CSV_FILE} missing required columns.")
                return pd.DataFrame()
            
            logging.info(f"Loaded {len(df)} uses for validation")
            return df
        except Exception as e:
            logging.error(f"Error loading {CSV_FILE}: {e}")
            return pd.DataFrame()

    @sleep_and_retry
    @limits(calls=CALLS_PER_MINUTE, period=PERIOD)
    @retry(
        stop=stop_after_attempt(5),
        wait=wait_exponential(multiplier=1, min=2, max=15),
        retry=retry_if_exception_type(Exception)
    )
    def validate_use(self, use, category):
        """Validate a single use using Gemini API"""
        try:
            prompt = VALIDATION_PROMPT.format(use=use, category=category)
            logging.info(f"Validating use: {use}")
            model = genai.GenerativeModel('gemini-2.5-flash-lite')
            response = model.generate_content(prompt)
            return response.text.strip()
        except Exception as e:
            logging.error(f"Validation failed for '{use}': {e}")
            raise

    def parse_validation_response(self, response):
        """Parse the LLM response into structured data"""
        lines = response.split('\n')
        valid = 'No'
        explanation = 'No response parsed'
        
        for line in lines:
            if line.startswith('Valid:'):
                valid = line.split(':', 1)[1].strip()
            elif line.startswith('Explanation:'):
                explanation = line.split(':', 1)[1].strip()
        
        return valid, explanation

    def validate_all(self):
        """Validate all uses and update the existing CSV with Valid and Explanation columns"""
        df = self.load_data()
        if df.empty:
            return pd.DataFrame()
        
        # Initialize new columns
        df['Valid'] = 'No'
        df['Explanation'] = ''
        
        validation_count = 0
        for index, row in df.iterrows():
            use = row['Use']
            category = row['Category']
            try:
                raw_response = self.validate_use(use, category)
                valid, explanation = self.parse_validation_response(raw_response)
                df.at[index, 'Valid'] = valid
                df.at[index, 'Explanation'] = explanation
            except Exception as e:
                logging.warning(f"Failed to validate '{use}': {e}. Marking as invalid.")
                df.at[index, 'Valid'] = 'No'
                df.at[index, 'Explanation'] = f"Validation failed: {str(e)}"
            
            validation_count += 1
            # Save every SAVE_INTERVAL validations
            if validation_count % SAVE_INTERVAL == 0:
                try:
                    df.to_csv(CSV_FILE, index=False, quoting=csv.QUOTE_NONNUMERIC)
                    logging.info(f"Incremental save after {validation_count} validations to {CSV_FILE}")
                except Exception as e:
                    logging.error(f"Error during incremental save after {validation_count} validations: {e}")
        
        # Final save
        try:
            df.to_csv(CSV_FILE, index=False, quoting=csv.QUOTE_NONNUMERIC)
            logging.info(f"Final save: Updated {CSV_FILE} with {len(df)} validated uses")
        except Exception as e:
            logging.error(f"Error saving {CSV_FILE}: {e}")
        
        return df

# Run the script
if __name__ == "__main__":
    try:
        validator = WireUsesValidator()
        df_validated = validator.validate_all()
        
        print("\n" + "="*60)
        print("VALIDATED CREATIVE USES FOR A SMALL METAL WIRE")
        print("="*60)
        
        if not df_validated.empty:
            print(f"\n✓ Total uses validated: {len(df_validated)}")
            print(f"✓ Valid uses: {len(df_validated[df_validated['Valid'] == 'Yes'])}")
            print(f"✓ Categories covered: {df_validated['Category'].nunique()}")
            print(f"\n📊 Uses per category:")
            print(df_validated['Category'].value_counts().head(10).to_string())
            print(f"\n📝 Sample validated uses:")
            print(df_validated[['Use', 'Category', 'Valid', 'Explanation']].sample(min(20, len(df_validated))).to_string(index=False))
        else:
            print("No uses validated.")
            
    except Exception as e:
        print(f"Error: {e}")
        logging.error(f"Full error details: {e}")
# Out:
# 2025-10-01 23:32:48,828 - INFO - Loaded 1086 uses for validation
# 2025-10-01 23:32:48,833 - INFO - Validating use: Bypass failed component
# 2025-10-01 23:32:50,571 - INFO - Validating use: Temporary test jumper
# 2025-10-01 23:32:51,365 - INFO - Validating use: Debug mode activation
# 2025-10-01 23:32:52,120 - INFO - Validating use: Circuit trace repair
# 2025-10-01 23:32:52,924 - INFO - Validating use: Power rail connection
# 2025-10-01 23:32:53,569 - INFO - Validating use: SMD Component Stabilizer
# 2025-10-01 23:32:54,447 - INFO - Validating use: Lead Bend Jig
# 2025-10-01 23:32:55,208 - INFO - Validating use: Micro-LED Positioner
# 2025-10-01 23:32:55,927 - INFO - Validating use: Battery Contact Shim
# 2025-10-01 23:32:56,719 - INFO - Validating use: Micro-Screw Holder
# 2025-10-01 23:32:57,495 - INFO - Validating use: Miniature Vine Trellis
# 2025-10-01 23:32:58,347 - INFO - Validating use: Dollhouse Coat Hanger
# 2025-10-01 23:32:59,236 - INFO - Validating use: Model Ship Rigging
# 2025-10-01 23:32:59,987 - INFO - Validating use: Micro Clay Armature
# 2025-10-01 23:33:00,805 - INFO - Validating use: Fairy Garden Gate Latch
# 2025-10-01 23:33:01,962 - INFO - Incremental save after 15 validations to paperclip_uses.csv
# 2025-10-01 23:33:48,824 - INFO - Validating use: SIM ejector tool
# 2025-10-01 23:33:49,638 - INFO - Validating use: Reset button poker
# 2025-10-01 23:33:50,876 - INFO - Validating use: Eyeglass screw tightener
# 2025-10-01 23:33:51,536 - INFO - Validating use: Clogged nozzle cleaner
# 2025-10-01 23:33:52,245 - INFO - Validating use: Temporary circuit bridge
# 2025-10-01 23:33:52,966 - INFO - Validating use: PCB Trace Tester
# 2025-10-01 23:33:53,774 - INFO - Validating use: Component Lead Validator
# 2025-10-01 23:33:54,601 - INFO - Validating use: Solder Joint Verifier
# 2025-10-01 23:33:55,299 - INFO - Validating use: Battery Contact Tester
# 2025-10-01 23:33:55,982 - INFO - Validating use: Connector Pin Tester
# 2025-10-01 23:33:56,646 - INFO - Validating use: Short Circuit Jumper
# 2025-10-01 23:33:57,441 - INFO - Validating use: Debug Mode Trigger
# 2025-10-01 23:33:58,165 - INFO - Validating use: Test Point Connection
# 2025-10-01 23:33:59,129 - INFO - Validating use: Temporary Ground Link
# 2025-10-01 23:33:59,882 - INFO - Validating use: LED Lead Holder
# 2025-10-01 23:34:00,698 - INFO - Incremental save after 30 validations to paperclip_uses.csv
# 2025-10-01 23:34:48,826 - INFO - Validating use: SMD Placement Aid
# 2025-10-01 23:34:49,669 - INFO - Validating use: Coin Cell Clamp
# 2025-10-01 23:34:50,403 - INFO - Validating use: Mini Heatsink Clip
# 2025-10-01 23:34:51,170 - INFO - Validating use: Component Leg Stabilizer
# 2025-10-01 23:34:51,898 - INFO - Validating use: Miniature Bonsai Armature
# 2025-10-01 23:34:52,503 - INFO - Validating use: Diorama Micro-Fence
# 2025-10-01 23:34:53,404 - INFO - Validating use: Tiny Figurine Skeleton
# 2025-10-01 23:34:54,274 - INFO - Validating use: Micro-Abstract Sculpture
# 2025-10-01 23:34:54,988 - INFO - Validating use: Dollhouse Hanging Rod
# 2025-10-01 23:34:55,765 - INFO - Validating use: Circuit jumper wire
# 2025-10-01 23:34:56,501 - INFO - Validating use: Small clog remover
# 2025-10-01 23:34:57,227 - INFO - Validating use: Temporary lock pick
# 2025-10-01 23:34:58,029 - INFO - Validating use: Splinter extraction tool
# 2025-10-01 23:34:58,837 - INFO - Validating use: Improvised fishing hook
# 2025-10-01 23:34:59,584 - INFO - Validating use: Test component leads
# 2025-10-01 23:35:00,242 - INFO - Incremental save after 45 validations to paperclip_uses.csv
# 2025-10-01 23:35:48,824 - INFO - Validating use: Verify solder joint
# 2025-10-01 23:35:49,432 - INFO - Validating use: Probe small connector
# 2025-10-01 23:35:50,279 - INFO - Validating use: Diagnose wire break
# 2025-10-01 23:35:51,094 - INFO - Validating use: Clear earbud mesh.
# 2025-10-01 23:35:51,827 - INFO - Validating use: Unclog pen nib.
# 2025-10-01 23:35:52,570 - INFO - Validating use: Clear nozzle tip.
# 2025-10-01 23:35:53,370 - INFO - Validating use: Clean watch stem.
# 2025-10-01 23:35:54,119 - INFO - Validating use: Clear glasses hinge.
# 2025-10-01 23:35:54,917 - INFO - Validating use: Short programming pins
# 2025-10-01 23:35:55,600 - INFO - Validating use: Prototype power jumper
# 2025-10-01 23:35:56,291 - INFO - Validating use: Bridge open circuit
# 2025-10-01 23:35:57,130 - INFO - Validating use: Solder component jig
# 2025-10-01 23:35:57,835 - INFO - Validating use: LED alignment tool
# 2025-10-01 23:35:58,650 - INFO - Validating use: Small wire loom
# 2025-10-01 23:35:59,392 - INFO - Validating use: Tiny screw retainer
# 2025-10-01 23:36:00,230 - INFO - Incremental save after 60 validations to paperclip_uses.csv
# 2025-10-01 23:36:48,825 - INFO - Validating use: PCB stand-off support
# 2025-10-01 23:36:49,619 - INFO - Validating use: Miniature Fence Post
# 2025-10-01 23:36:50,355 - INFO - Validating use: Model Vehicle Antenna
# 2025-10-01 23:36:51,030 - INFO - Validating use: Diorama Tree Branch
# 2025-10-01 23:36:51,655 - INFO - Validating use: Tiny Rebar Simulation
# 2025-10-01 23:36:52,501 - INFO - Validating use: Micro-sculpture Armature
# 2025-10-01 23:36:53,123 - INFO - Validating use: Sim card ejector
# 2025-10-01 23:36:53,785 - INFO - Validating use: Battery contact repair
# 2025-10-01 23:36:54,596 - INFO - Validating use: Broken zipper fix
# 2025-10-01 23:36:55,306 - INFO - Validating use: Small button resetter
# 2025-10-01 23:36:56,165 - INFO - Validating use: Connect loose contacts
# 2025-10-01 23:36:56,796 - INFO - Validating use: Probe SMD pads
# 2025-10-01 23:36:57,428 - INFO - Validating use: Ground small component
# 2025-10-01 23:36:58,072 - INFO - Validating use: Probe PCB lines
# 2025-10-01 23:36:58,767 - INFO - Validating use: Clear charging port
# 2025-10-01 23:36:59,564 - INFO - Incremental save after 75 validations to paperclip_uses.csv
# 2025-10-01 23:37:48,817 - INFO - Validating use: Unclog spray nozzle
# 2025-10-01 23:37:49,546 - INFO - Validating use: Open glue bottle
# 2025-10-01 23:37:50,407 - INFO - Validating use: Clear 3D printer nozzle
# 2025-10-01 23:37:51,259 - INFO - Validating use: Bridge test points
# 2025-10-01 23:37:52,112 - INFO - Validating use: Check micro-continuity
# 2025-10-01 23:37:52,918 - INFO - Validating use: Bypass blown fuse
# 2025-10-01 23:37:53,867 - INFO - Validating use: Reroute circuit signal
# 2025-10-01 23:37:54,598 - INFO - Validating use: Position small LED
# 2025-10-01 23:37:55,377 - INFO - Validating use: Retrieve dropped screw
# 2025-10-01 23:37:56,069 - INFO - Validating use: Angle micro-sensor
# 2025-10-01 23:37:56,813 - INFO - Validating use: Form custom mini-hook
# 2025-10-01 23:37:57,641 - INFO - Validating use: Reinforce miniature joint
# 2025-10-01 23:37:58,263 - INFO - Validating use: Unclog tiny sprayer
# 2025-10-01 23:37:59,066 - INFO - Validating use: Clear micro-jet
# 2025-10-01 23:37:59,809 - INFO - Validating use: Open printer head
# 2025-10-01 23:38:00,581 - INFO - Incremental save after 90 validations to paperclip_uses.csv
# 2025-10-01 23:38:48,817 - INFO - Validating use: Extract slot lint
# 2025-10-01 23:38:49,480 - INFO - Validating use: Clean airbrush nozzle
# 2025-10-01 23:38:50,211 - INFO - Validating use: Secure bread bag.
# 2025-10-01 23:38:51,080 - INFO - Validating use: Attach key tag.
# 2025-10-01 23:38:51,892 - INFO - Validating use: Mend broken glasses.
# 2025-10-01 23:38:52,589 - INFO - Validating use: Hang lightweight ornament.
# 2025-10-01 23:38:53,322 - INFO - Validating use: Bind small bundle.
# 2025-10-01 23:38:54,043 - INFO - Validating use: Shape small symbols
# 2025-10-01 23:38:54,772 - INFO - Validating use: Twist sensory stim
# 2025-10-01 23:38:55,458 - INFO - Validating use: Finger dexterity exercise
# 2025-10-01 23:38:56,173 - INFO - Validating use: Explore wire texture
# 2025-10-01 23:38:56,958 - INFO - Validating use: Pocket calming aid
# 2025-10-01 23:38:57,731 - INFO - Validating use: Check circuit continuity
# 2025-10-01 23:38:58,404 - INFO - Validating use: Probe signal path
# 2025-10-01 23:38:59,192 - INFO - Validating use: Short pins momentarily
# 2025-10-01 23:38:59,955 - INFO - Incremental save after 105 validations to paperclip_uses.csv
# 2025-10-01 23:39:48,818 - INFO - Validating use: Tiny clay shaper
# 2025-10-01 23:39:49,592 - INFO - Validating use: Watch escapement tuner
# 2025-10-01 23:39:50,444 - INFO - Validating use: Insect leg splint
# 2025-10-01 23:39:51,222 - INFO - Validating use: Unclog print nozzle
# 2025-10-01 23:39:51,955 - INFO - Validating use: Clear airbrush tip
# 2025-10-01 23:39:52,854 - INFO - Validating use: Dislodge headphone debris
# 2025-10-01 23:39:53,548 - INFO - Validating use: Clean watch gear teeth
# 2025-10-01 23:39:54,307 - INFO - Validating use: Unblock glue nozzle
# 2025-10-01 23:39:55,059 - INFO - Validating use: Secure loose button
# 2025-10-01 23:39:55,708 - INFO - Validating use: Seal snack bag
# 2025-10-01 23:39:56,447 - INFO - Validating use: Create miniature hook
# 2025-10-01 23:39:57,129 - INFO - Validating use: Bendable shape meditation
# 2025-10-01 23:39:57,953 - INFO - Validating use: Kinetic finger sculpture
# 2025-10-01 23:39:58,652 - INFO - Validating use: Tactile resistance press
# 2025-10-01 23:39:59,284 - INFO - Validating use: Cool wire tracing
# 2025-10-01 23:40:00,034 - INFO - Incremental save after 120 validations to paperclip_uses.csv
# 2025-10-01 23:40:48,822 - INFO - Validating use: Micro-loop formation
# 2025-10-01 23:40:49,632 - INFO - Validating use: SMD Pin Straightener
# 2025-10-01 23:40:50,483 - INFO - Validating use: Micro Switch Activator
# 2025-10-01 23:40:51,269 - INFO - Validating use: Tiny Latch Release
# 2025-10-01 23:40:52,040 - INFO - Validating use: Component Positioning Aid
# 2025-10-01 23:40:52,848 - INFO - Validating use: Potentiometer Shaft Adjuster
# 2025-10-01 23:40:53,732 - INFO - Validating use: Small Screw Retrieval
# 2025-10-01 23:40:54,468 - INFO - Validating use: Port Debris Hook
# 2025-10-01 23:40:55,294 - INFO - Validating use: Stuck Card Extractor
# 2025-10-01 23:40:55,973 - INFO - Validating use: Micro Bead Grabber
# 2025-10-01 23:40:56,799 - INFO - Validating use: Recessed Item Lifter
# 2025-10-01 23:40:57,590 - INFO - Validating use: Solder Gap Former
# 2025-10-01 23:40:58,269 - INFO - Validating use: Component Lead Bender
# 2025-10-01 23:40:59,044 - INFO - Validating use: Micro-Loop Jig
# 2025-10-01 23:40:59,900 - INFO - Validating use: Nozzle Clearing Gauge
# 2025-10-01 23:41:00,661 - INFO - Incremental save after 135 validations to paperclip_uses.csv
# 2025-10-01 23:41:48,819 - INFO - Validating use: Wire Bend Guide
# 2025-10-01 23:41:49,590 - INFO - Validating use: Tiny Adhesive Spatula
# 2025-10-01 23:41:50,349 - INFO - Validating use: Micro Part Holder
# 2025-10-01 23:41:51,004 - INFO - Validating use: Crevice Dust Picker
# 2025-10-01 23:41:51,832 - INFO - Validating use: Mini Paint Stirrer
# 2025-10-01 23:41:52,541 - INFO - Validating use: SMD Aligner Tool
# 2025-10-01 23:41:53,291 - INFO - Validating use: Chip Static Zapper
# 2025-10-01 23:41:54,024 - INFO - Validating use: Fabric Static Neutralizer
# 2025-10-01 23:41:55,003 - INFO - Validating use: Lens Static Eraser
# 2025-10-01 23:41:55,875 - INFO - Validating use: Key Static Discharger
# 2025-10-01 23:41:56,592 - INFO - Validating use: Plastic Part Static Drain
# 2025-10-01 23:41:57,511 - INFO - Validating use: Microswitch contact bender
# 2025-10-01 23:41:58,212 - INFO - Validating use: Delicate spring re-positioner
# 2025-10-01 23:41:59,063 - INFO - Validating use: Connector pin realigner
# 2025-10-01 23:41:59,737 - INFO - Validating use: SMD component nudger
# 2025-10-01 23:42:00,555 - INFO - Incremental save after 150 validations to paperclip_uses.csv
# 2025-10-01 23:42:48,822 - INFO - Validating use: Small mechanism linkage adjuster
# 2025-10-01 23:42:49,658 - INFO - Validating use: Fallen screw retriever
# 2025-10-01 23:42:50,395 - INFO - Validating use: Debris gap fisher
# 2025-10-01 23:42:51,073 - INFO - Validating use: Extract lodged SIM
# 2025-10-01 23:42:51,738 - INFO - Validating use: Snag earring back
# 2025-10-01 23:42:52,408 - INFO - Validating use: Retrieve watch spring
# 2025-10-01 23:42:53,144 - INFO - Validating use: Component lead jig
# 2025-10-01 23:42:53,867 - INFO - Validating use: Micro-bore sizer
# 2025-10-01 23:42:54,583 - INFO - Validating use: Filament spacing guide
# 2025-10-01 23:42:55,223 - INFO - Validating use: Wire insulation gauge
# 2025-10-01 23:42:55,914 - INFO - Validating use: Tiny Glue Applicator
# 2025-10-01 23:42:56,749 - INFO - Validating use: Model Part Positioner
# 2025-10-01 23:42:57,498 - INFO - Validating use: Resin Bubble Popper
# 2025-10-01 23:42:58,186 - INFO - Validating use: Micro-Texture Stylus
# 2025-10-01 23:42:58,905 - INFO - Validating use: Paint Chip Restorer
# 2025-10-01 23:42:59,702 - INFO - Incremental save after 165 validations to paperclip_uses.csv
# 2025-10-01 23:43:48,814 - INFO - Validating use: Ground body charge
# 2025-10-01 23:43:49,552 - INFO - Validating use: Component static neutralizer
# 2025-10-01 23:43:50,405 - INFO - Validating use: Lens static dissipator
# 2025-10-01 23:43:51,241 - INFO - Validating use: Micro-device ground point
# 2025-10-01 23:43:51,841 - INFO - Validating use: Sensitive area de-static
# 2025-10-01 23:43:52,667 - INFO - Validating use: Micro-LED heat path
# 2025-10-01 23:43:53,495 - INFO - Validating use: Spot cooling conductor
# 2025-10-01 23:43:54,249 - INFO - Validating use: Solder spot heater
# 2025-10-01 23:43:55,070 - INFO - Validating use: Sensor heat conduit
# 2025-10-01 23:43:55,876 - INFO - Validating use: Local anti-ice element
# 2025-10-01 23:43:56,658 - INFO - Validating use: Dollhouse miniature rail
# 2025-10-01 23:43:57,459 - INFO - Validating use: Model detail antenna
# 2025-10-01 23:43:58,710 - INFO - Validating use: Tiny charm loop
# 2025-10-01 23:43:59,471 - INFO - Validating use: Fairy garden fence
# 2025-10-01 23:44:00,201 - INFO - Validating use: Circuit interruption trigger
# 2025-10-01 23:44:01,053 - INFO - Incremental save after 180 validations to paperclip_uses.csv
# 2025-10-01 23:44:48,821 - INFO - Validating use: Seam distortion flag
# 2025-10-01 23:44:49,713 - INFO - Validating use: Module seating confirmation
# 2025-10-01 23:44:50,386 - INFO - Validating use: Housing opening obstruction
# 2025-10-01 23:44:51,188 - INFO - Validating use: Fastener rotation telltale
# 2025-10-01 23:44:52,114 - INFO - Validating use: Micro-droplet applicator
# 2025-10-01 23:44:52,761 - INFO - Validating use: Particle sifting tool
# 2025-10-01 23:44:53,519 - INFO - Validating use: Fiber extraction probe
# 2025-10-01 23:44:54,137 - INFO - Validating use: Gel consistency tester
# 2025-10-01 23:44:54,896 - INFO - Validating use: Crystal shard mover
# 2025-10-01 23:44:55,568 - INFO - Validating use: Resonance Seeker
# 2025-10-01 23:44:56,426 - INFO - Validating use: Density Tapper
# 2025-10-01 23:44:57,191 - INFO - Validating use: Alignment Tapper
# 2025-10-01 23:44:57,991 - INFO - Validating use: Void Tapper
# 2025-10-01 23:44:58,787 - INFO - Validating use: Sensor Response Tapper
# 2025-10-01 23:44:59,640 - INFO - Validating use: Thermal Flow Inducer
# 2025-10-01 23:45:00,567 - INFO - Incremental save after 195 validations to paperclip_uses.csv
# 2025-10-01 23:45:48,819 - INFO - Validating use: Localized Heat Spreader
# 2025-10-01 23:45:49,641 - INFO - Validating use: Micro Temperature Sensor
# 2025-10-01 23:45:50,475 - INFO - Validating use: Heat Dissipation Trace
# 2025-10-01 23:45:51,247 - INFO - Validating use: Targeted Thermal Link
# 2025-10-01 23:45:52,270 - INFO - Validating use: Miniature Pendant Loop
# 2025-10-01 23:45:52,947 - INFO - Validating use: Dollhouse Chandelier Arm
# 2025-10-01 23:45:53,733 - INFO - Validating use: Tiny Embellishment Curl
# 2025-10-01 23:45:54,391 - INFO - Validating use: Model Railing Detail
# 2025-10-01 23:45:55,133 - INFO - Validating use: Small Ornament Hanger
# 2025-10-01 23:45:55,965 - INFO - Validating use: Screw turn breach
# 2025-10-01 23:45:56,784 - INFO - Validating use: Circuit disconnect flag
# 2025-10-01 23:45:57,545 - INFO - Validating use: Cover integrity witness
# 2025-10-01 23:45:58,312 - INFO - Validating use: Joint separation marker
# 2025-10-01 23:45:59,526 - INFO - Validating use: Micro access seal
# 2025-10-01 23:46:00,235 - INFO - Validating use: Micro-sample stirrer
# 2025-10-01 23:46:01,059 - INFO - Incremental save after 210 validations to paperclip_uses.csv
# 2025-10-01 23:46:48,813 - INFO - Validating use: Tiny particle extractor
# 2025-10-01 23:46:49,427 - INFO - Validating use: Fiber alignment guide
# 2025-10-01 23:46:50,290 - INFO - Validating use: Gel spreading tool
# 2025-10-01 23:46:50,896 - INFO - Validating use: Void detection sounder
# 2025-10-01 23:46:51,704 - INFO - Validating use: Circuit continuity tapper
# 2025-10-01 23:46:52,552 - INFO - Validating use: Resonance tuning wire
# 2025-10-01 23:46:53,257 - INFO - Validating use: Delicate structure vibrator
# 2025-10-01 23:46:53,970 - INFO - Validating use: Substrate density probe
# 2025-10-01 23:46:54,659 - INFO - Validating use: Emergency Radio Whip
# 2025-10-01 23:46:56,469 - INFO - Validating use: Wearable Sensor Link
# 2025-10-01 23:46:57,308 - INFO - Validating use: Proximity Field Generator
# 2025-10-01 23:46:58,281 - INFO - Validating use: Micro-RFID Coil
# 2025-10-01 23:46:59,123 - INFO - Validating use: Temporary RF Extender
# 2025-10-01 23:47:00,097 - INFO - Validating use: 3D Nozzle Unclog Pick
# 2025-10-01 23:47:00,829 - INFO - Validating use: Airbrush Channel Clearer
# 2025-10-01 23:47:01,588 - INFO - Incremental save after 225 validations to paperclip_uses.csv
# 2025-10-01 23:47:48,825 - INFO - Validating use: Medical Needle Unblocker
# 2025-10-01 23:47:49,592 - INFO - Validating use: Instrument Orifice Probe
# 2025-10-01 23:47:50,295 - INFO - Validating use: Capillary Tube Reamer
# 2025-10-01 23:47:51,104 - INFO - Validating use: Micro-bead Stringer
# 2025-10-01 23:47:51,891 - INFO - Validating use: LED Lead Threader
# 2025-10-01 23:47:52,669 - INFO - Validating use: Small Wire Puller
# 2025-10-01 23:47:53,581 - INFO - Validating use: Fiber Optic Guide
# 2025-10-01 23:47:54,246 - INFO - Validating use: Miniature Connector Threader
# 2025-10-01 23:47:55,015 - INFO - Validating use: Wire bundle cinch
# 2025-10-01 23:47:55,779 - INFO - Validating use: Component alignment holder
# 2025-10-01 23:47:56,488 - INFO - Validating use: Battery terminal bridge
# 2025-10-01 23:47:57,328 - INFO - Validating use: Mini panel latch
# 2025-10-01 23:47:58,252 - INFO - Validating use: PCB component holddown
# 2025-10-01 23:47:58,899 - INFO - Validating use: Point-contact probe
# 2025-10-01 23:47:59,691 - INFO - Validating use: Neural stimulator
# 2025-10-01 23:48:00,458 - INFO - Incremental save after 240 validations to paperclip_uses.csv
# 2025-10-01 23:48:48,819 - INFO - Validating use: Cell potential sensor
# 2025-10-01 23:48:49,687 - INFO - Validating use: Micro-electrolysis tip
# 2025-10-01 23:48:50,469 - INFO - Validating use: Signal injection probe
# 2025-10-01 23:48:51,386 - INFO - Validating use:  RFID tag antenna
# 2025-10-01 23:48:52,003 - INFO - Validating use:  NFC communication coil
# 2025-10-01 23:48:52,853 - INFO - Validating use:  On-body sensor telemetry
# 2025-10-01 23:48:53,583 - INFO - Validating use:  EM field test antenna
# 2025-10-01 23:48:54,277 - INFO - Validating use:  Wireless power coil
# 2025-10-01 23:48:55,094 - INFO - Validating use: Inkjet printhead unclogger
# 2025-10-01 23:48:55,784 - INFO - Validating use: Charging port lint remover
# 2025-10-01 23:48:56,534 - INFO - Validating use: Micro-tubing blockage probe
# 2025-10-01 23:48:57,242 - INFO - Validating use: Miniature bead threader
# 2025-10-01 23:48:57,875 - INFO - Validating use: Micro-suture pilot
# 2025-10-01 23:48:58,595 - INFO - Validating use: Connector pin aligner
# 2025-10-01 23:48:59,400 - INFO - Validating use: Micro-eyelet line threader
# 2025-10-01 23:49:00,169 - INFO - Incremental save after 255 validations to paperclip_uses.csv
# 2025-10-01 23:49:48,813 - INFO - Validating use: Pin component leads
# 2025-10-01 23:49:49,620 - INFO - Validating use: Bundle tiny wires
# 2025-10-01 23:49:50,296 - INFO - Validating use: Attach small heatsink
# 2025-10-01 23:49:51,201 - INFO - Validating use: Hold miniature gears
# 2025-10-01 23:49:52,004 - INFO - Validating use: Secure battery contact
# 2025-10-01 23:49:52,655 - INFO - Validating use: Neural Signal Reader
# 2025-10-01 23:49:53,409 - INFO - Validating use: Cellular Stimulus Emitter
# 2025-10-01 23:49:54,152 - INFO - Validating use: Biosensor Point Contact
# 2025-10-01 23:49:54,834 - INFO - Validating use: Microfluidic Sample Dipper
# 2025-10-01 23:49:55,609 - INFO - Validating use: Subcellular Voltage Probe
# 2025-10-01 23:49:56,374 - INFO - Validating use: *   Micro-clearance check
# 2025-10-01 23:49:57,141 - INFO - Validating use: *   Electrical contact gauge
# 2025-10-01 23:49:57,900 - INFO - Validating use: *   Solder bridge detector
# 2025-10-01 23:49:58,574 - INFO - Validating use: *   Nozzle orifice gauge
# 2025-10-01 23:49:59,245 - INFO - Validating use: *   Fine gap shim
# 2025-10-01 23:50:00,045 - INFO - Incremental save after 270 validations to paperclip_uses.csv
# 2025-10-01 23:50:48,813 - INFO - Validating use:  Breadboard test link
# 2025-10-01 23:50:49,632 - INFO - Validating use:  Short circuit diagnostic
# 2025-10-01 23:50:50,282 - INFO - Validating use:  Fuse bypass link
# 2025-10-01 23:50:51,015 - INFO - Validating use: *   Micro-component prop
# 2025-10-01 23:50:51,747 - INFO - Validating use: *   Fragile joint splint
# 2025-10-01 23:50:52,471 - INFO - Validating use: *   Tiny item holder
# 2025-10-01 23:50:53,194 - INFO - Validating use: *   Miniature pivot pin
# 2025-10-01 23:50:53,809 - INFO - Validating use: *   Small form guide
# 2025-10-01 23:50:54,522 - INFO - Validating use: Insect wing spreader
# 2025-10-01 23:50:55,263 - INFO - Validating use: Petal positioner
# 2025-10-01 23:50:56,051 - INFO - Validating use: Micro-crystal holder
# 2025-10-01 23:50:56,825 - INFO - Validating use: Microorganism restraint loop
# 2025-10-01 23:50:57,608 - INFO - Validating use: Anther alignment clip
# 2025-10-01 23:50:58,416 - INFO - Validating use: Port lint extractor
# 2025-10-01 23:50:59,487 - INFO - Validating use: Nozzle clog probe
# 2025-10-01 23:51:00,301 - INFO - Incremental save after 285 validations to paperclip_uses.csv
# 2025-10-01 23:51:48,818 - INFO - Validating use: Splinter removal pick
# 2025-10-01 23:51:49,480 - INFO - Validating use: Watch gear debris
# 2025-10-01 23:51:50,233 - INFO - Validating use: Micro-screw retriever
# 2025-10-01 23:51:50,893 - INFO - Validating use: Solder bridge check
# 2025-10-01 23:51:51,669 - INFO - Validating use: Lead spacing verify
# 2025-10-01 23:51:52,431 - INFO - Validating use: Bearing play gauge
# 2025-10-01 23:51:53,212 - INFO - Validating use: Micro-hinge clearance
# 2025-10-01 23:51:53,998 - INFO - Validating use: Bridge broken trace
# 2025-10-01 23:51:54,817 - INFO - Validating use: Simulate switch closure
# 2025-10-01 23:51:55,515 - INFO - Validating use: Set mode pin
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 122
#     120 try:
#     121     validator = WireUsesValidator()
# --> 122     df_validated = validator.validate_all()
#     124     print("\n" + "="*60)
#     125     print("VALIDATED CREATIVE USES FOR A SMALL METAL WIRE")
#
# Cell In[2], line 91, in WireUsesValidator.validate_all(self)
#      89 category = row['Category']
#      90 try:
# ---> 91     raw_response = self.validate_use(use, category)
#      92     valid, explanation = self.parse_validation_response(raw_response)
#      93     df.at[index, 'Valid'] = valid
#
# File F:\miniconda3\Lib\site-packages\ratelimit\decorators.py:113, in sleep_and_retry.<locals>.wrapper(*args, **kargs)
#     111 while True:
#     112     try:
# --> 113         return func(*args, **kargs)
#     114     except RateLimitException as exception:
#     115         time.sleep(exception.period_remaining)
#
# File F:\miniconda3\Lib\site-packages\ratelimit\decorators.py:80, in RateLimitDecorator.__call__.<locals>.wrapper(*args, **kargs)
#      77             raise RateLimitException('too many calls', period_remaining)
#      78         return
# ---> 80 return func(*args, **kargs)
#
# File F:\miniconda3\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File F:\miniconda3\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File F:\miniconda3\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File F:\miniconda3\Lib\site-packages\tenacity\__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File F:\miniconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File F:\miniconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File F:\miniconda3\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# Cell In[2], line 56, in WireUsesValidator.validate_use(self, use, category)
#      54     logging.info(f"Validating use: {use}")
#      55     model = genai.GenerativeModel('gemini-2.5-flash-lite')
# ---> 56     response = model.generate_content(prompt)
#      57     return response.text.strip()
#      58 except Exception as e:
#
# File F:\miniconda3\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File F:\miniconda3\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File F:\miniconda3\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File F:\miniconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File F:\miniconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File F:\miniconda3\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File F:\miniconda3\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File F:\miniconda3\Lib\site-packages\grpc\_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)    275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File F:\miniconda3\Lib\site-packages\grpc\_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File F:\miniconda3\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\transports\grpc.py:79, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)     76         },
#      77     )
# ---> 79 response = continuation(client_call_details, request)
#      80 if logging_enabled:  # pragma: NO COVER
#      81     response_metadata = response.trailing_metadata()
#
# File F:\miniconda3\Lib\site-packages\grpc\_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)    312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File F:\miniconda3\Lib\site-packages\grpc\_channel.py:1192, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)   1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
# -> 1192     state, call = self._blocking(
#    1193         request, timeout, metadata, credentials, wait_for_ready, compression
#    1194     )
#    1195     return _end_unary_response_blocking(state, call, True, None)
#
# File F:\miniconda3\Lib\site-packages\grpc\_channel.py:1165, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1148 state.target = _common.decode(self._target)
#    1149 call = self._channel.segregated_call(
#    1150     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1151     self._method,
#    (...)   1163     self._registered_call_handle,
#    1164 )
# -> 1165 event = call.next_event()
#    1166 _handle_event(event, state, self._response_deserializer)
#    1167 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:
